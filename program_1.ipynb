# %% [markdown]
# <a href="https://colab.research.google.com/github/ABINAYA600/GENAI_LAB/blob/main/program_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
# Load pretrained GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Load pretrained GPT-2 model
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Input prompt
prompt = "Artificial Intelligence is"

# Convert prompt into tokens
inputs = tokenizer.encode(
    prompt,
    return_tensors="pt"
)

# Generate text
outputs = model.generate(
    inputs,
    max_length=100,
    num_return_sequences=1,
    temperature=0.7,
    do_sample=True
)

# Decode generated text
generated_text = tokenizer.decode(
    outputs[0],
    skip_special_tokens=True
)

print("Generated Text:")
print(generated_text)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Generated Text:
# Artificial Intelligence is a natural extension of the scientific method; and it is the first one to become part of the scientific method.
#
# The purpose of the artificial intelligence study in this way is not to give a clear, comprehensive picture of what a scientist is doing. The purpose of the study is not to make a list of specific scientific disciplines, and the purpose of the study does not have to be a scientific description of the results of science. The purpose of the study is to provide scientific methods
